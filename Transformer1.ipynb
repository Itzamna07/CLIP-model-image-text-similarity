# %%
pip install sentence_transformers

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #creacion csv y limpieza de datos

# %%
import pandas as pd

# Ruta al archivo en Google Drive
ruta_csv = '/content/drive/MyDrive/pruebasNadia/Extraer IMG/dataimg.csv'
ruta_csv_acl = '/content/drive/MyDrive/acl_datos_completos.csv'

# Leer el archivo CSV y convertirlo en un DataFrame
df = pd.read_csv(ruta_csv)
df_acl = pd.read_csv(ruta_csv_acl)

# Copiar el contenido de la columna "Accepted" en las filas correspondientes de df
for index, row in df.iterrows():
    archivo = row['archivo']
    accepted_value = df_acl.loc[df_acl['Archivo'] == archivo, 'Accepted'].values
    if len(accepted_value) > 0:
        df.at[index, 'label'] = accepted_value[0]

# Ruta para guardar el archivo modificado
ruta_guardado = '/content/drive/MyDrive/pruebasNadia/Extraer IMG/dataimg.csv'

# Guardar el DataFrame modificado en la nueva ruta
df.to_csv(ruta_guardado, index=False)

print("DataFrame modificado guardado en:", ruta_guardado)
# Out:
# DataFrame modificado guardado en: /content/drive/MyDrive/pruebasNadia/Extraer IMG/dataimg.csv

# %%
import pandas as pd

# Ruta al archivo en Google Drive
ruta_csv = '/content/drive/MyDrive/pruebasNadia/iclr_img/data.csv'
ruta_csv_acl = '/content/drive/MyDrive/iclr_datos_completos.csv'

# Leer el archivo CSV y convertirlo en un DataFrame
df = pd.read_csv(ruta_csv, encoding='latin1')  #'latin1', 'iso-8859-1' o 'cp1252'
print(df.head())
print(df.columns)
df_acl = pd.read_csv(ruta_csv_acl)
#print (df_acl)

#if 'Etiqueta' not in df.columns:
#    # Si no está presente, agregar la columna al DataFrame con valores NaN
#    df['Etiqueta '] = None

# Copiar el contenido de la columna "Accepted" en las filas correspondientes de df
for index, row in df.iterrows():
    archivo = row['archivo']  # Accede a la columna sin espacio en el nombre
    accepted_value = df_acl.loc[df_acl['Archivo'] == archivo, 'Accepted'].values
    if len(accepted_value) > 0:
        df.at[index, 'label'] = accepted_value[0]

print(df)

# Ruta para guardar el archivo modificado
ruta_guardado = '/content/drive/MyDrive/pruebasNadia/iclr_img/CSV_Papers_labeled2.csv'

# Guardar el DataFrame modificado en la nueva ruta
df.to_csv(ruta_guardado, index=False)

print("DataFrame modificado guardado en:", ruta_guardado)

# %%
import pandas as pd

# Ruta al archivo en Google Drive
ruta_csv = '/content/drive/MyDrive/pruebasNadia/iclr_img/data3.xlsx'
ruta_csv_acl = '/content/drive/MyDrive/iclr_datos_completos.csv'

# Leer el archivo CSV y convertirlo en un DataFrame
df = pd.read_excel(ruta_csv)  #'latin1', 'iso-8859-1' o 'cp1252'
print(df.head())
print(df.columns)
df_acl = pd.read_csv(ruta_csv_acl)
#print (df_acl)

#if 'Etiqueta' not in df.columns:
#    # Si no está presente, agregar la columna al DataFrame con valores NaN
#    df['Etiqueta '] = None

# Copiar el contenido de la columna "Accepted" en las filas correspondientes de df
for index, row in df.iterrows():
    archivo = row['archivo']  # Accede a la columna sin espacio en el nombre
    accepted_value = df_acl.loc[df_acl['Archivo'] == archivo, 'Accepted'].values
    if len(accepted_value) > 0:
        df.at[index, 'label'] = accepted_value[0]

print(df)

# Ruta para guardar el archivo modificado
ruta_guardado = '/content/drive/MyDrive/pruebasNadia/iclr_img/CSV_Papers_labeled2.csv'

# Guardar el DataFrame modificado en la nueva ruta
df.to_csv(ruta_guardado, index=False)

print("DataFrame modificado guardado en:", ruta_guardado)

# %%
import pandas as pd

# Ruta al archivo en Google Drive
ruta_csv = '/content/drive/MyDrive/pruebasNadia/Extraer IMG/dataimg.csv'
ruta_csv_acl = '/content/drive/MyDrive/acl_datos_completos.csv'

# Leer el archivo CSV y convertirlo en un DataFrame
df = pd.read_csv(ruta_csv)
df_acl = pd.read_csv(ruta_csv_acl)

# Copiar el contenido de la columna "Accepted" en las filas correspondientes de df
for index, row in df.iterrows():
    archivo = row['archivo']
    accepted_value = df_acl.loc[df_acl['Archivo'] == archivo, 'Accepted'].values
    if len(accepted_value) > 0:
        df.at[index, 'label'] = accepted_value[0]

# Eliminar filas con datos vacíos en las columnas especificadas ('archivo' y 'label')
df_cleaned = df.dropna(subset=['archivo', 'texto_figura'])

# Ruta para guardar el archivo modificado
ruta_guardado = '/content/drive/MyDrive/pruebasNadia/Extraer IMG/dataimg_cleaned.csv'

# Guardar el DataFrame limpio en la nueva ruta
df_cleaned.to_csv(ruta_guardado, index=False)

print("DataFrame modificado y limpio guardado en:", ruta_guardado)
# Out:
# DataFrame modificado y limpio guardado en: /content/drive/MyDrive/pruebasNadia/Extraer IMG/dataimg_cleaned.csv

# %%
import pandas as pd

# Ruta al archivo en Google Drive
ruta_csv = '/content/drive/MyDrive/pruebasNadia/iclr_img/data.csv'
ruta_csv_acl = '/content/drive/MyDrive/iclr_datos_completos.csv'

# Leer el archivo CSV y convertirlo en un DataFrame
df = pd.read_csv(ruta_csv, encoding='latin1')  #'latin1', 'iso-8859-1' o 'cp1252'
print(df.head())
print(df.columns)
df_acl = pd.read_csv(ruta_csv_acl)
#print (df_acl)


# Copiar el contenido de la columna "Accepted" en las filas correspondientes de df
for index, row in df.iterrows():
    archivo = row['archivo']  # Accede a la columna sin espacio en el nombre
    accepted_value = df_acl.loc[df_acl['Archivo'] == archivo, 'Accepted'].values
    if len(accepted_value) > 0:
        df.at[index, 'label'] = accepted_value[0]

print(df)

# Ruta para guardar el archivo modificado
ruta_guardado = '/content/drive/MyDrive/pruebasNadia/iclr_img/CSV_Papers_labeled2.csv'

# Guardar el DataFrame modificado en la nueva ruta
df.to_csv(ruta_guardado, index=False)

print("DataFrame modificado guardado en:", ruta_guardado)

# %%
import pandas as pd

# Ruta al archivo en Google Drive
ruta_csv = '/content/drive/MyDrive/pruebasNadia/Extraer IMG/dataimg_iclr_similaridad_stopwords.csv'
ruta_csv_acl = '/content/drive/MyDrive/iclr_datos_completos.csv'

# Leer el archivo CSV y convertirlo en un DataFrame
df = pd.read_csv(ruta_csv, encoding='latin1')  #'latin1', 'iso-8859-1' o 'cp1252'
print(df.head())
print(df.columns)
df_acl = pd.read_csv(ruta_csv_acl)
#print (df_acl)


# Copiar el contenido de la columna "Accepted" en las filas correspondientes de df
for index, row in df.iterrows():
    archivo = row['archivo']  # Accede a la columna sin espacio en el nombre
    accepted_value = df_acl.loc[df_acl['Archivo'] == archivo, 'Accepted'].values
    if len(accepted_value) > 0:
        df.at[index, 'label'] = accepted_value[0]

print(df)

# Ruta para guardar el archivo modificado
ruta_guardado = '/content/drive/MyDrive/pruebasNadia/iclr_img/CSV_iclr_stop_labeled_2.csv'

# Guardar el DataFrame modificado en la nueva ruta
df.to_csv(ruta_guardado, index=False)

print("DataFrame modificado guardado en:", ruta_guardado)

# %% [markdown]
# # similaridad pruebas

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer, util
from PIL import Image
import os

# Ruta al archivo en Google Drive
ruta_csv = '/content/drive/MyDrive/pruebasNadia/Extraer IMG/dataimg.csv'

# Leer el archivo CSV y convertirlo en un DataFrame
df = pd.read_csv(ruta_csv)
print(df.head())

# Seleccionar modelo preentrenado
#model = SentenceTransformer('clip-ViT-B-32')
model = SentenceTransformer('clip-ViT-L-14')

# Lista para almacenar las puntuaciones de similitud
similarity_scores = []

# Iterar sobre cada fila del df
for index, row in df.iterrows():
    # Obtener los valores de las columnas para la fila actual
    archivo = row['archivo']
    figura = row['figura']
    texto_figura = row['texto_figura']
    label = row['label']
    ruta = row['ruta']
    ruta_completa = os.path.join('/content/drive/MyDrive/pruebasNadia/Extraer IMG/', ruta,figura +".png")
    print(ruta_completa)


    # Encode an image:
    img_emb = model.encode(Image.open(ruta_completa))

    # Encode text description
    text_emb = model.encode([texto_figura])

    # Compute cosine similarities
    cos_scores = util.cos_sim(img_emb, text_emb)

    # Agregar el resultado de la similitud al DataFrame
    similarity_scores.append(cos_scores[0])

    # Resultados
    print(f"Archivo: {archivo}, Figura: {figura}, Label: {label}, Similaridad: {cos_scores}")

# Agregar una nueva columna con las similaridades de cada figura
df['similaridad'] = similarity_scores

# Guardar el nuevo DataFrame con la columna de similitud como un nuevo archivo CSV
ruta_nuevo_csv = '/content/drive/MyDrive/ruta/al/dataimg_con_similaridad.csv'
df.to_csv(ruta_nuevo_csv, index=False)
print(df.head())

# Imprimir mensaje de confirmación
print(f"Archivo CSV con la columna 'similaridad' guardado en: {ruta_nuevo_csv}")

# %%
pip install torch

# %%
from transformers import AutoTokenizer, AutoModel

# Cargar el tokenizador y el modelo desde Hugging Face
tokenizer = AutoTokenizer.from_pretrained("nombre-del-modelo-o-la-ruta-al-modelo-en-disco")
model = AutoModel.from_pretrained("nombre-del-modelo-o-la-ruta-al-modelo-en-disco")

# Oraciones que deseas codificar
sentences = ['Esta es la primera oración.', 'Esta es la segunda oración.']

# Tokenizar las oraciones
encoded_input = tokenizer(sentences, padding=True, truncation=True, max_length=128, return_tensors='pt')

# Calcular las incrustaciones (embeddings)
with torch.no_grad():
    model_output = model(**encoded_input)

# Realizar pooling, por ejemplo, mean pooling
token_embeddings = model_output.last_hidden_state
attention_mask = encoded_input['attention_mask'].unsqueeze(-1).expand(token_embeddings.size())
sum_embeddings = torch.sum(token_embeddings * attention_mask, dim=1)
sum_mask = torch.clamp(attention_mask.sum(1), min=1e-9)
sentence_embeddings = sum_embeddings / sum_mask

# Las embeddings de las oraciones estarán en sentence_embeddings

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer, util
from PIL import Image
import os
import torch

# Ruta al archivo en Google Drive
ruta_csv = '/content/drive/MyDrive/pruebasNadia/Extraer IMG/dataimg_cleaned2.csv'

# Leer el archivo CSV y convertirlo en un DataFrame
df = pd.read_csv(ruta_csv)
print(df.head())

# Seleccionar modelo preentrenado
model = SentenceTransformer('clip-ViT-B-32', device='cuda')

# Lista para almacenar las puntuaciones de similitud
similarity_scores = []

# Iterar sobre cada fila del df
for index, row in df.iterrows():
    # Obtener los valores de las columnas para la fila actual
    archivo = row['archivo']
    figura = row['figura']
    texto_figura = row['texto_figura']
    label = row['label']
    ruta = row['ruta']

    # Verificar si ruta y figura son valores válidos
    if ruta and figura:
        ruta_completa = os.path.join('/content/drive/MyDrive/pruebasNadia/Extraer IMG/', str(ruta), figura + ".png")

        # Encode an image
        img_emb = model.encode(Image.open(ruta_completa), convert_to_tensor=True)

        # Encode text description using mean pooling
        text_embeddings = model.encode([texto_figura], convert_to_tensor=True)
        attention_mask = torch.ones_like(text_embeddings)  # Attention mask with ones for all tokens
        text_emb = torch.sum(text_embeddings * attention_mask, dim=1) / torch.sum(attention_mask, dim=1)

        # Ensure compatible dimensions for multiplication
        text_emb = text_emb.squeeze(0)
        # Asegurarte de que text_emb tenga las mismas dimensiones que img_emb
        text_emb_expanded = text_emb.expand_as(img_emb)

        # Calcular las puntuaciones de similitud del coseno
        cos_scores = util.pytorch_cos_sim(img_emb, text_emb_expanded).item()

        # Agregar el resultado de la similitud al DataFrame
        similarity_scores.append(cos_scores)

        # Resultados
        print(f"Archivo: {archivo}, Figura: {figura}, Label: {label}, Similaridad: {cos_scores}")

    else:
        # Si ruta o figura son nulos, continuar con la próxima iteración
        continue

# Agregar una nueva columna con las similaridades de cada figura
df['similaridad'] = similarity_scores

# Guardar el nuevo DataFrame con la columna de similitud como un nuevo archivo CSV
ruta_nuevo_csv = '/content/drive/MyDrive/ruta/al/dataimg_con_similaridad_pruebita.csv'
df.to_csv(ruta_nuevo_csv, index=False)
print(df.head())

# Imprimir mensaje de confirmación
print(f"Archivo CSV con la columna 'similaridad' guardado en: {ruta_nuevo_csv}")

# %% [markdown]
# #Similaridad FINAL

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer, util
from PIL import Image
import os
import re
import torch

# ruta archivo
ruta_csv = '/content/drive/MyDrive/pruebasNadia/Extraer IMG/dataimg.csv'

# leer el archivo csv y convertirlo en DataFrame
df = pd.read_csv(ruta_csv)
print(df.head())

# Función para contar las palabras en un texto
def contar_palabras(texto):
    # Comprobar si el valor es nulo (NaN)
    if isinstance(texto, str):
        palabras = texto.split()
        return len(palabras)
    else:
        # Si el valor es nulo devolver valor reuerido
        return 0

# Función para limpiar texto
def limpiar_texto(texto):
    # Comprobar si el valor es nulo (NaN)
    if isinstance(texto, str):

        texto_limpio = re.sub(r'[^\x00-\x7F]+', ' ', texto)  # Eliminar caracteres no en inglés
        texto_limpio = re.sub(r'[^\w\s]', '', texto_limpio)  # Eliminar signos de puntuación
        texto_limpio = re.sub(r'\s+', ' ', texto_limpio).strip()  # Reemplazar espacios dobles por uno solo
        return texto_limpio
    else:
        # Si el valor es nulo devolver valor asignado
        return ''


def similaridad(texto,ruta):
  text_tokens = model.tokenize([texto])
  #print(text_tokens)
  num_tokens = len(text_tokens['input_ids'][0])
  print(num_tokens)

  if num_tokens <= 77:
    # Encode an image:
    print(ruta)
    img_emb = model.encode(Image.open(ruta), convert_to_tensor=True)

    text_emb = model.encode([texto], convert_to_tensor=True)
    # Ensure compatible dimensions for multiplication
    text_emb = text_emb.squeeze(0)
    # escalar text_emb para que tenga las mismas dimensiones que img_emb
    text_emb_expanded = text_emb.expand_as(img_emb)

    # Compute cosine similarities
    cos_scores = util.cos_sim(img_emb, text_emb_expanded)
    return cos_scores
  else:
    # Dividir el texto exactamente a la mitad
    longitud_texto = len(texto)
    mitad = longitud_texto // 2
    fragmento1 = texto[:mitad]
    fragmento2 = texto[mitad:]

    # Llamar recursivamente la función similaridad para ambos fragmentos
    cos_scores1 = similaridad(fragmento1, ruta)
    cos_scores2 = similaridad(fragmento2, ruta)

    # Calcular el promedio de las similitudes de ambos fragmentos
    promedio_similitudes = (cos_scores1 + cos_scores2) / 2
    return promedio_similitudes


# Agregar nueva columna llamada "tamano"
df['tamano'] = df['texto_figura'].apply(contar_palabras)

# Seleccionar modelo preentrenado
model = SentenceTransformer('clip-ViT-B-32')
#model = SentenceTransformer('clip-ViT-B-32', device='cuda')

# Lista para almacenar las puntuaciones de similitud
similarity_scores = []

# Iterar sobre cada fila del df
for index, row in df.iterrows():
    # Obtener los valores de las columnas para la fila actual
    archivo = row['archivo']
    figura = row['figura']
    texto_figura = row['texto_figura']
    label = row['label']
    ruta = row['ruta']

    # Limitar la longitud del texto
    texto_figura_limpio = limpiar_texto(texto_figura)
    # Encode text description
    print(texto_figura_limpio)

    # Verificar si ruta y figura son valores válidos
    if ruta and isinstance(figura, str):
        #ruta_completa = os.path.join('/content/drive/MyDrive/pruebasNadia/Extraer IMG/', ruta, figura + ".png")
        ruta_completa = os.path.join('/content/drive/MyDrive/pruebasNadia/Extraer IMG/', str(ruta), figura + ".png")

        #obtenet similaridad
        cos_scores = similaridad(texto_figura_limpio,ruta_completa)
        # Agregar el resultado de la similitud al DataFrame

        # Obtener similitud como valor numérico
        cos_score_numeric = cos_scores.item()
        print(cos_score_numeric)

        # Agregar el resultado de la similitud al DataFrame
        similarity_scores.append(cos_score_numeric)

        # Resultados
        print(f"Archivo: {archivo}, Figura: {figura}, Label: {label}, Similaridad: {cos_scores}")

    else:
        # Si ruta o figura no son válidos asignar la frase y continuar
        similaridad_frase = "No contiene IMÁGENES"
        similarity_scores.append(similaridad_frase)
        print(f"Archivo: {archivo}, Figura: {figura}, Label: {label}, Similaridad: {similaridad_frase}")
        continue

# Agregar una nueva columna con las similaridades de cada figura
similaridad_scores_cpu = [score.cpu().numpy()[0] if isinstance(score, torch.Tensor) else score for score in similarity_scores]
df['similaridad'] = similaridad_scores_cpu

# Guardar el nuevo DataFrame con la columna 'tamano' y 'similaridad' como un nuevo archivo CSV
ruta_nuevo_csv = '/content/drive/MyDrive/pruebasNadia/Extraer IMG/dataimg_con_similaridad.csv'
df.to_csv(ruta_nuevo_csv, index=False)
print(df.head())

# Imprimir mensaje de confirmación
print(f"Archivo CSV con las columnas 'tamano' y 'similaridad' guardado en: {ruta_nuevo_csv}")

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer, util
from PIL import Image
import os
import re
import torch

# ruta archivo
ruta_csv1 = '/content/drive/MyDrive/pruebasNadia/iclr_img/CSV_Papers_labeled - CSV_Papers_labeled (2).csv'
ruta_csv2 = '/content/drive/MyDrive/pruebasNadia/iclr_img/CSV_Papers_labeled2.csv'
# leer el archivo csv y convertirlo en DataFrame
df1 = pd.read_csv(ruta_csv1)
df2 = pd.read_csv(ruta_csv2)
df = pd.concat([df1, df2], ignore_index=True)
print(df.head())

# Función para contar las palabras en un texto
def contar_palabras(texto):
    # Comprobar si el valor es nulo (NaN)
    if isinstance(texto, str):
        palabras = texto.split()
        return len(palabras)
    else:
        # Si el valor es nulo devolver valor reuerido
        return 0

# Función para limpiar texto
def limpiar_texto(texto):
    # Comprobar si el valor es nulo (NaN)
    if isinstance(texto, str):

        texto_limpio = re.sub(r'[^\x00-\x7F]+', ' ', texto)  # Eliminar caracteres no en inglés
        texto_limpio = re.sub(r'[^\w\s]', '', texto_limpio)  # Eliminar signos de puntuación
        texto_limpio = re.sub(r'\s+', ' ', texto_limpio).strip()  # Reemplazar espacios dobles por uno solo
        return texto_limpio
    else:
        # Si el valor es nulo devolver valor asignado
        return ''


def similaridad(texto,ruta):
  text_tokens = model.tokenize([texto])
  #print(text_tokens)
  num_tokens = len(text_tokens['input_ids'][0])
  print(num_tokens)

  if num_tokens <= 77:
    # Encode an image:
    print(ruta)
    img_emb = model.encode(Image.open(ruta), convert_to_tensor=True)

    text_emb = model.encode([texto], convert_to_tensor=True)
    # Ensure compatible dimensions for multiplication
    text_emb = text_emb.squeeze(0)
    # escalar text_emb para que tenga las mismas dimensiones que img_emb
    text_emb_expanded = text_emb.expand_as(img_emb)

    # Compute cosine similarities
    cos_scores = util.cos_sim(img_emb, text_emb_expanded)
    return cos_scores
  else:
    # Dividir el texto exactamente a la mitad
    longitud_texto = len(texto)
    mitad = longitud_texto // 2
    fragmento1 = texto[:mitad]
    fragmento2 = texto[mitad:]

    # Llamar recursivamente la función similaridad para ambos fragmentos
    cos_scores1 = similaridad(fragmento1, ruta)
    cos_scores2 = similaridad(fragmento2, ruta)

    # Calcular el promedio de las similitudes de ambos fragmentos
    promedio_similitudes = (cos_scores1 + cos_scores2) / 2
    return promedio_similitudes

# Agregar nueva columna llamada "tamano"
df['tamano'] = df['texto_figura'].apply(contar_palabras)

# Seleccionar modelo preentrenado
model = SentenceTransformer('clip-ViT-B-32')
#model = SentenceTransformer('clip-ViT-B-32', device='cuda')

# Lista para almacenar las puntuaciones de similitud
similarity_scores = []

# Iterar sobre cada fila del df
for index, row in df.iterrows():
    # Obtener los valores de las columnas para la fila actual
    archivo = row['archivo']
    figura = row['figura']
    texto_figura = row['texto_figura']
    label = row['label']
    ruta = row['ruta']

    # Limitar la longitud del texto
    texto_figura_limpio = limpiar_texto(texto_figura)
    # Encode text description
    print(texto_figura_limpio)

    # Verificar si ruta y figura son valores válidos
    if ruta and isinstance(figura, str):
        ruta_completa = os.path.join('/content/drive/MyDrive/pruebasNadia/iclr_img/', str(ruta), figura + ".png")

        #obtenet similaridad
        cos_scores = similaridad(texto_figura_limpio,ruta_completa)
        # Agregar el resultado de la similitud al DataFrame

        # Obtener similitud como valor numérico
        cos_score_numeric = cos_scores.item()
        print(cos_score_numeric)

        # Agregar el resultado de la similitud al DataFrame
        similarity_scores.append(cos_score_numeric)

        # Resultados
        print(f"Archivo: {archivo}, Figura: {figura}, Label: {label}, Similaridad: {cos_scores}")

    else:
        # Si ruta o figura no son válidos asignar la frase y continuar
        similaridad_frase = "No contiene IMÁGENES"
        similarity_scores.append(similaridad_frase)
        print(f"Archivo: {archivo}, Figura: {figura}, Label: {label}, Similaridad: {similaridad_frase}")
        continue

# Agregar una nueva columna con las similaridades de cada figura
similaridad_scores_cpu = [score.cpu().numpy()[0] if isinstance(score, torch.Tensor) else score for score in similarity_scores]
df['similaridad'] = similaridad_scores_cpu

# Guardar el nuevo DataFrame con la columna 'tamano' y 'similaridad' como un nuevo archivo CSV
ruta_nuevo_csv = '/content/drive/MyDrive/pruebasNadia/iclr_img/dataimg_con_similaridad_stop.csv'
df.to_csv(ruta_nuevo_csv, index=False)
print(df.head())

# Imprimir mensaje de confirmación
print(f"Archivo CSV con las columnas 'tamano' y 'similaridad' guardado en: {ruta_nuevo_csv}")

# %% [markdown]
# #FINAL CON STOPWORDS

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer, util
from sklearn.feature_extraction.text import CountVectorizer, ENGLISH_STOP_WORDS
from PIL import Image
import os
import re
import nltk
import torch

# Ruta al archivo en Google Drive
ruta_csv = '/content/drive/MyDrive/pruebasNadia/Extraer IMG/dataimg.csv'

# Leer el archivo CSV y convertirlo en un DataFrame
df = pd.read_csv(ruta_csv)
print(df.head())

nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

# Función para contar las palabras en un texto
def contar_palabras(texto):
    # Comprobar si el valor es nulo (NaN)
    if isinstance(texto, str):
        palabras = texto.split()
        return len(palabras)
    else:
        # Si el valor es nulo devolver valor 0
        return 0

# Función para limpiar texto
def limpiar_texto(texto):
    # Comprobar si el valor es nulo (NaN)
    if isinstance(texto, str):

        texto_limpio = re.sub(r'[^\x00-\x7F]+', ' ', texto)  # Eliminar caracteres no en inglés
        texto_limpio = re.sub(r'[^\w\s]', '', texto_limpio)  # Eliminar signos de puntuación
        texto_limpio = re.sub(r'\s+', ' ', texto_limpio).strip()  # Reemplazar espacios dobles por uno solo

        # Filtrar stopwords en inglés
        words = texto_limpio.split()
        filtered_words = [word for word in words if word.lower() not in stop_words]
        texto_filtrado = ' '.join(filtered_words)

        return texto_filtrado
    else:
        # Si el valor es nulo devolver valor asignado
        return ''


def similaridad(texto,ruta):
  text_tokens = model.tokenize([texto])
  #print(text_tokens)
  num_tokens = len(text_tokens['input_ids'][0])
  print(num_tokens)

  if num_tokens <= 77:
    # Encode an image:
    print(ruta)
    img_emb = model.encode(Image.open(ruta), convert_to_tensor=True)

    text_emb = model.encode([texto], convert_to_tensor=True)
    # Ensure compatible dimensions for multiplication
    text_emb = text_emb.squeeze(0)
    # Asegurarte de que text_emb tenga las mismas dimensiones que img_emb
    text_emb_expanded = text_emb.expand_as(img_emb)

    # Compute cosine similarities
    cos_scores = util.cos_sim(img_emb, text_emb_expanded)
    return cos_scores
  else:
    # Dividir el texto exactamente a la mitad
    longitud_texto = len(texto)
    mitad = longitud_texto // 2
    fragmento1 = texto[:mitad]
    fragmento2 = texto[mitad:]

    # Llamar recursivamente la función similaridad para ambos fragmentos
    cos_scores1 = similaridad(fragmento1, ruta)
    cos_scores2 = similaridad(fragmento2, ruta)

    # Calcular el promedio de las similitudes de ambos fragmentos
    promedio_similitudes = (cos_scores1 + cos_scores2) / 2
    return promedio_similitudes

# Agregar nueva columna llamada "tamano"
df['tamano'] = df['texto_figura'].apply(contar_palabras)

# Seleccionar modelo preentrenado
model = SentenceTransformer('clip-ViT-B-32')
#model = SentenceTransformer('clip-ViT-B-32', device='cuda')

# Lista para almacenar las puntuaciones de similitud
similarity_scores = []

# Iterar sobre cada fila del df
for index, row in df.iterrows():
    # Obtener los valores de las columnas para la fila actual
    archivo = row['archivo']
    figura = row['figura']
    texto_figura = row['texto_figura']
    label = row['label']
    ruta = row['ruta']

    # Limitar la longitud del texto
    texto_figura_limpio = limpiar_texto(texto_figura)
    # Encode text description
    print(texto_figura_limpio)

    # Verificar si ruta y figura son valores válidos
    if ruta and isinstance(figura, str):
        #ruta_completa = os.path.join('/content/drive/MyDrive/pruebasNadia/Extraer IMG/', ruta, figura + ".png")
        ruta_completa = os.path.join('/content/drive/MyDrive/pruebasNadia/Extraer IMG/', str(ruta), figura + ".png")

        vectorizer = CountVectorizer()
        texto_vectorizado = vectorizer.fit_transform([texto_figura_limpio])
        texto_vectorizado_str = ' '.join(vectorizer.inverse_transform(texto_vectorizado)[0].astype(str))

        #obtenet similaridad
        cos_scores = similaridad(texto_vectorizado_str,ruta_completa)
        # Agregar el resultado de la similitud al DataFrame

        # Obtener similitud como valor numérico
        cos_score_numeric = cos_scores.item()
        print(cos_score_numeric)

        # Agregar el resultado de la similitud al DataFrame
        similarity_scores.append(cos_score_numeric)

        # Resultados
        print(f"Archivo: {archivo}, Figura: {figura}, Label: {label}, Similaridad: {cos_scores}")

    else:
        # Si ruta o figura no son válidos, asignar la frase y continuar con la próxima iteración
        similaridad_frase = "No contiene IMÁGENES"
        similarity_scores.append(similaridad_frase)
        print(f"Archivo: {archivo}, Figura: {figura}, Label: {label}, Similaridad: {similaridad_frase}")
        continue

# Agregar una nueva columna con las similaridades de cada figura
similaridad_scores_cpu = [score.cpu().numpy()[0] if isinstance(score, torch.Tensor) else score for score in similarity_scores]
df['similaridad'] = similaridad_scores_cpu

# Guardar el nuevo DataFrame con la columna 'tamano' y 'similaridad' como un nuevo archivo CSV
ruta_nuevo_csv = '/content/drive/MyDrive/pruebasNadia/Extraer IMG/dataimg_con_similaridad_stopwords.csv'
df.to_csv(ruta_nuevo_csv, index=False)
print(df.head())

# Imprimir mensaje de confirmación
print(f"Archivo CSV con las columnas 'tamano' y 'similaridad' guardado en: {ruta_nuevo_csv}")

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer, util
from sklearn.feature_extraction.text import CountVectorizer, ENGLISH_STOP_WORDS
from PIL import Image
import os
import re
import nltk
import torch

# ruta archivo
ruta_csv1 = '/content/drive/MyDrive/pruebasNadia/iclr_img/CSV_Papers_labeled - CSV_Papers_labeled (2).csv'
ruta_csv2 = '/content/drive/MyDrive/pruebasNadia/iclr_img/CSV_Papers_labeled2.csv'
# leer el archivo csv y convertirlo en DataFrame
df1 = pd.read_csv(ruta_csv1)
df2 = pd.read_csv(ruta_csv2)
df = pd.concat([df1, df2], ignore_index=True)
print(df.head())

nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

# Función para contar las palabras en un texto
def contar_palabras(texto):
    # Comprobar si el valor es nulo (NaN)
    if isinstance(texto, str):
        palabras = texto.split()
        return len(palabras)
    else:
        # Si el valor es nulo devolver valor 0
        return 0

# Función para limpiar texto
def limpiar_texto(texto):
    # Comprobar si el valor es nulo (NaN)
    if isinstance(texto, str):

        texto_limpio = re.sub(r'[^\x00-\x7F]+', ' ', texto)  # Eliminar caracteres no en inglés
        texto_limpio = re.sub(r'[^\w\s]', '', texto_limpio)  # Eliminar signos de puntuación
        texto_limpio = re.sub(r'\s+', ' ', texto_limpio).strip()  # Reemplazar espacios dobles por uno solo

        # Filtrar stopwords en inglés
        words = texto_limpio.split()
        filtered_words = [word for word in words if word.lower() not in stop_words]
        texto_filtrado = ' '.join(filtered_words)

        return texto_filtrado
    else:
        # Si el valor es nulo devolver valor asignado
        return ''


def similaridad(texto,ruta):
  text_tokens = model.tokenize([texto])
  #print(text_tokens)
  num_tokens = len(text_tokens['input_ids'][0])
  print(num_tokens)

  if num_tokens <= 77:
    # Encode an image:
    print(ruta)
    img_emb = model.encode(Image.open(ruta), convert_to_tensor=True)

    text_emb = model.encode([texto], convert_to_tensor=True)
    # Ensure compatible dimensions for multiplication
    text_emb = text_emb.squeeze(0)
    # Asegurarte de que text_emb tenga las mismas dimensiones que img_emb
    text_emb_expanded = text_emb.expand_as(img_emb)

    # Compute cosine similarities
    cos_scores = util.cos_sim(img_emb, text_emb_expanded)
    return cos_scores
  else:
    # Dividir el texto exactamente a la mitad
    longitud_texto = len(texto)
    mitad = longitud_texto // 2
    fragmento1 = texto[:mitad]
    fragmento2 = texto[mitad:]

    # Llamar recursivamente la función similaridad para ambos fragmentos
    cos_scores1 = similaridad(fragmento1, ruta)
    cos_scores2 = similaridad(fragmento2, ruta)

    # Calcular el promedio de las similitudes de ambos fragmentos
    promedio_similitudes = (cos_scores1 + cos_scores2) / 2
    return promedio_similitudes

# Agregar nueva columna llamada "tamano"
df['tamano'] = df['texto_figura'].apply(contar_palabras)

# Seleccionar modelo preentrenado
model = SentenceTransformer('clip-ViT-B-32')
#model = SentenceTransformer('clip-ViT-B-32', device='cuda')

# Lista para almacenar las puntuaciones de similitud
similarity_scores = []

# Iterar sobre cada fila del df
for index, row in df.iterrows():
    # Obtener los valores de las columnas para la fila actual
    archivo = row['archivo']
    figura = row['figura']
    texto_figura = row['texto_figura']
    label = row['label']
    ruta = row['ruta']

    # Limitar la longitud del texto
    texto_figura_limpio = limpiar_texto(texto_figura)
    # Encode text description
    print(texto_figura_limpio)

    # Verificar si ruta y figura son valores válidos
    if ruta and isinstance(figura, str):
        ruta_completa = os.path.join('/content/drive/MyDrive/pruebasNadia/iclr_img/', str(ruta), figura + ".png")

        vectorizer = CountVectorizer()
        texto_vectorizado = vectorizer.fit_transform([texto_figura_limpio])
        texto_vectorizado_str = ' '.join(vectorizer.inverse_transform(texto_vectorizado)[0].astype(str))

        #obtenet similaridad
        cos_scores = similaridad(texto_vectorizado_str,ruta_completa)
        # Agregar el resultado de la similitud al DataFrame

        # Obtener similitud como valor numérico
        cos_score_numeric = cos_scores.item()
        print(cos_score_numeric)

        # Agregar el resultado de la similitud al DataFrame
        similarity_scores.append(cos_score_numeric)

        # Resultados
        print(f"Archivo: {archivo}, Figura: {figura}, Label: {label}, Similaridad: {cos_scores}")

    else:
        # Si ruta o figura no son válidos, asignar la frase y continuar con la próxima iteración
        similaridad_frase = "No contiene IMÁGENES"
        similarity_scores.append(similaridad_frase)
        print(f"Archivo: {archivo}, Figura: {figura}, Label: {label}, Similaridad: {similaridad_frase}")
        continue

# Agregar una nueva columna con las similaridades de cada figura
similaridad_scores_cpu = [score.cpu().numpy()[0] if isinstance(score, torch.Tensor) else score for score in similarity_scores]
df['similaridad'] = similaridad_scores_cpu

# Guardar el nuevo DataFrame con la columna 'tamano' y 'similaridad' como un nuevo archivo CSV
ruta_nuevo_csv = '/content/drive/MyDrive/pruebasNadia/Extraer IMG/dataimg_iclr_similaridad_stopwords.csv'
df.to_csv(ruta_nuevo_csv, index=False)
print(df.head())

# Imprimir mensaje de confirmación
print(f"Archivo CSV con las columnas 'tamano' y 'similaridad' guardado en: {ruta_nuevo_csv}")
# Out:
#    archivo    figura                                       texto_figura  \
# 0  304.pdf  Figure 1  Addition Task. The non-recursive trace loops o...
# 1  304.pdf  Figure 2  Bubble Sort Task. The non-recursive trace loop...
# 2  304.pdf   Table 1  Accuracy on Randomly Generated Problems for Bu...
# 3  304.pdf   Table 2  Accuracy on Randomly Generated Problems for To...
# 4  304.pdf   Table 3  Accuracy on Randomly Generated Problems for Qu...
#
#    label                ruta
# 0    NaN  img_iclr/train/304
# 1    NaN  img_iclr/train/304
# 2    NaN  img_iclr/train/304
# 3    NaN  img_iclr/train/304
# 4    NaN  img_iclr/train/304
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Addition Task nonrecursive trace loops cycles ADD 1 LSHIFT whereas recursive version ADD function calls bolded
# 21
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/304/Figure 1.png
# 0.29588502645492554
# Archivo: 304.pdf, Figura: Figure 1, Label: nan, Similaridad: tensor([[0.2959]], device='cuda:0')
# Bubble Sort Task nonrecursive trace loops cycles BUBBLE RESET difference partial recursive full recursive versions indentation Lines 1015 2022 bolded since full recursive version BSTEP LSHIFT made tail recursive final calls BSTEP LSHIFT return immediately occur pointer reaches end array Also note COMPSWAP conditionally swaps numbers bubble pointers
# 58
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/304/Figure 2.png
# 0.27217692136764526
# Archivo: 304.pdf, Figura: Figure 2, Label: nan, Similaridad: tensor([[0.2722]], device='cuda:0')
# Accuracy Randomly Generated Problems Bubble Sort
# 8
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/304/Table 1.png
# 0.2648971378803253
# Archivo: 304.pdf, Figura: Table 1, Label: nan, Similaridad: tensor([[0.2649]], device='cuda:0')
# Accuracy Randomly Generated Problems Topological Sort
# 9
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/304/Table 2.png
# 0.2389540821313858
# Archivo: 304.pdf, Figura: Table 2, Label: nan, Similaridad: tensor([[0.2390]], device='cuda:0')
# Accuracy Randomly Generated Problems Quicksort
# 8
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/304/Table 3.png
# 0.284088134765625
# Archivo: 304.pdf, Figura: Table 3, Label: nan, Similaridad: tensor([[0.2841]], device='cuda:0')
# Accuracy Randomly Generated Problems Variant Bubble Sort
# 9
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/304/Table 4.png
# Token indices sequence length is longer than the specified maximum sequence length for this model (98 > 77). Running this sequence through the model will result in indexing errors
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# 0.26352459192276
# Archivo: 735.pdf, Figura: Figure_2, Label: nan, Similaridad: tensor([[0.2635]], device='cuda:0')
# 3D reconstruction errors linear nonlinear dimensionality regularization ground truth camera poses Column 4 gives gives error TNH column 23 56 gives corresponding error proposed method different width RBF kernel Row 5 reports mean error 4 sequences
# 41
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/735/Table_2.png
# 0.2855217754840851
# Archivo: 735.pdf, Figura: Table_2, Label: nan, Similaridad: tensor([[0.2855]], device='cuda:0')
# Robust dimensionality reduction accuracy KPCA versus closedform solution full oil flow dataset Columns left right represent 1 standard deviation noise training samples 23 Error estimated lowdimensional kernel matrix 2 KPCA 3 closedform solution 45 Nearest neighbor classification error test data using 4 KPCA 5 closedform solution respectively Manifold Error Classification Error KPCA CFS KPCA CFS 01099 01068 960 960 02298 02184 1990 1570 03522 03339 4010 2220
# 99
# 33
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/735/Table_3.png
# 68
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/735/Table_3.png
# 0.31871938705444336
# Archivo: 735.pdf, Figura: Table_3, Label: nan, Similaridad: tensor([[0.3187]], device='cuda:0')
# Performance comparison KPCA Robust closedform solution dimensionality regularization oil flow dataset additive Gaussian noise standard deviation 7 Plots show normal ized kernel matrix errors different rank model Kernel PCA results shown dotted line diamond solid line star Barplot show worst best errors obtained method single rank recovered kernel matrix
# 54
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/735/Figure_3.png
# 0.30699101090431213
# Archivo: 735.pdf, Figura: Figure_3, Label: nan, Similaridad: tensor([[0.3070]], device='cuda:0')
# 3D reconstruction errors linear nonlinear dimensionality regularization noisy camera pose initialization rigid factorization refined alternation shape format Table2
# 30
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/735/Table_4.png
# 0.2830701768398285
# Archivo: 735.pdf, Figura: Table_4, Label: nan, Similaridad: tensor([[0.2831]], device='cuda:0')
# 3D reconstruction errors different NRSfM approaches TNH Algorith camera projection matrices Results methods except TNH taken fromDai
# 27
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/735/Table_5.png
# 0.23915937542915344
# Archivo: 735.pdf, Figura: Table_5, Label: nan, Similaridad: tensor([[0.2392]], device='cuda:0')
# Illustration proposed method convolutional fully connected layer use different biasvariance terms perform batch normalization training domain test domain domain specific normalization mitigates domain shift issue
# 30
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/736/Figure_1.png
# 0.29262927174568176
# Archivo: 736.pdf, Figura: Figure_1, Label: nan, Similaridad: tensor([[0.2926]], device='cuda:0')
# tSNE Van der Maaten Hinton 2008 visualization minibatch BN feature vector distributions shallow deep layers across different datasets point represents BN statistics one minibatch Red dots come Bing domain blue ones Caltech256 domain size minibatch 64
# 47
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/736/Figure_2.png
# 0.31549274921417236
# Archivo: 736.pdf, Figura: Figure_2, Label: nan, Similaridad: tensor([[0.3155]], device='cuda:0')
# Single source domain adaptation results Office31 Saenko et al 2010 dataset standard unsupervised adaptation protocol
# 24
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/736/Table_1.png
# 0.2545655071735382
# Archivo: 736.pdf, Figura: Table_1, Label: nan, Similaridad: tensor([[0.2546]], device='cuda:0')
# Multisource domain adaptation results Office31 Saenko et al 2010 dataset standard unsupervised adaptation protocol
# 24
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/736/Table_2.png
# 0.283343642950058
# Archivo: 736.pdf, Figura: Table_2, Label: nan, Similaridad: tensor([[0.2833]], device='cuda:0')
# Single source domain adaptation results CaltechBing Bergamo Torresani 2010 dataset
# 20
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/736/Table_3.png
# 0.25988271832466125
# Archivo: 736.pdf, Figura: Table_3, Label: nan, Similaridad: tensor([[0.2599]], device='cuda:0')
# Accuracy varying number minibatches used calculating statistics BN layers W B C respectively B C show results using less 100 batches since results sTable_when adding examples batch size 64 experiment even smaller number examples performance may consistent drop behind baseline eg 0652 16 samples 0661 32 samples
# 57
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/736/Figure_3.png
# 0.28396445512771606
# Archivo: 736.pdf, Figura: Figure_3, Label: nan, Similaridad: tensor([[0.2840]], device='cuda:0')
# Accuracy adapting different BN blocks B C 0 corresponds
# 9
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/736/Figure_4.png
# 0.3072567582130432
# Archivo: 736.pdf, Figura: Figure_4, Label: nan, Similaridad: tensor([[0.3073]], device='cuda:0')
# Domain adaptation results mIOU GFI Tianhui datasets training GF2 datasets
# 16
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/736/Table_4.png
# 0.2859586775302887
# Archivo: 736.pdf, Figura: Table_4, Label: nan, Similaridad: tensor([[0.2860]], device='cuda:0')
# Remote sensing images different domains
# 7
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/736/Figure_5.png
# 0.3507884442806244
# Archivo: 736.pdf, Figura: Figure_5, Label: nan, Similaridad: tensor([[0.3508]], device='cuda:0')
# Visual cloud detection results GF1 dataset White pixels b c represent detected cloud regions
# 15
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/736/Figure_6.png
# 0.298675000667572
# Archivo: 736.pdf, Figura: Figure_6, Label: nan, Similaridad: tensor([[0.2987]], device='cuda:0')
# Microarchitectural view Organization convolution filters Fire module example siz1 3 121 4 e33 4 illustrate convolution filters activations
# 24
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/737/Figure_1.png
# 0.3209536373615265
# Archivo: 737.pdf, Figura: Figure_1, Label: nan, Similaridad: tensor([[0.3210]], device='cuda:0')
# Macroarchitectural view SqueezeNet architecture Left SqueezeNet Section33 Middle SqueezeNet simple bypass Section6 Right SqueezeNet complex bypass Sec
# 21
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/737/Figure_2.png
# 0.23132437467575073
# Archivo: 737.pdf, Figura: Figure_2, Label: nan, Similaridad: tensor([[0.2313]], device='cuda:0')
# SqueezeNet architectural dimensions formatting Table_was inspired
# 13
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/737/Table_1.png
# 0.30326226353645325
# Archivo: 737.pdf, Figura: Table_1, Label: nan, Similaridad: tensor([[0.3033]], device='cuda:0')
# Comparing SqueezeNet model compression approaches model size mean number bytes required store parameters trained model
# 17
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/737/Table_2.png
# 0.3168478310108185
# Archivo: 737.pdf, Figura: Table_2, Label: nan, Similaridad: tensor([[0.3168]], device='cuda:0')
# Microarchitectural design space exploration
# 7
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/737/Figure_3.png
# 0.23112624883651733
# Archivo: 737.pdf, Figura: Figure_3, Label: nan, Similaridad: tensor([[0.2311]], device='cuda:0')
# SqueezeNet accuracy model size using different macroarchitecture configurations
# 14
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/737/Table_3.png
# 0.26367974281311035
# Archivo: 737.pdf, Figura: Table_3, Label: nan, Similaridad: tensor([[0.2637]], device='cuda:0')
# MAC algorithm binary autoencoders parfor indicates loop whose iterations carried parallel steps h f run parallel well
# 21
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/740/Figure_1.png
# 0.2847038209438324
# Archivo: 740.pdf, Figura: Figure_1, Label: nan, Similaridad: tensor([[0.2847]], device='cuda:0')
# ParMAC model P 4 machines 12 submodels w N 40 data points Submodels h h h 2M h 3M copies submodel h one currently updated end W step copies identical
# 27
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/740/Figure_2.png
# 0.2763517498970032
# Archivo: 740.pdf, Figura: Figure_2, Label: nan, Similaridad: tensor([[0.2764]], device='cuda:0')
# Precision CIFAR dataset
# 7
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/740/Figure_3.png
# 0.2633260488510132
# Archivo: 740.pdf, Figura: Figure_3, Label: nan, Similaridad: tensor([[0.2633]], device='cuda:0')
# Speedup SP function number machines P top experiment bottom theory dataset size number submodels N 50 000 32 CIFAR 10 32 SIFT1M 108 128 SIFT1B
# 42
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/740/Figure_4.png
# 0.3203178942203522
# Archivo: 740.pdf, Figura: Figure_4, Label: nan, Similaridad: tensor([[0.3203]], device='cuda:0')
# raise three questions application methodology technique perspectives spectively provide answers case study simplest chess game tictactoe
# 23
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/741/Figure_1.png
# 0.237641379237175
# Archivo: 741.pdf, Figura: Figure_1, Label: nan, Similaridad: tensor([[0.2376]], device='cuda:0')
# 18 different types chessboard states corresponding labels
# 12
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/741/Figure_2.png
# 0.30552998185157776
# Archivo: 741.pdf, Figura: Figure_2, Label: nan, Similaridad: tensor([[0.3055]], device='cuda:0')
# Class activation mapping results dataset
# 8
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/741/Figure_3.png
# 0.30385294556617737
# Archivo: 741.pdf, Figura: Figure_3, Label: nan, Similaridad: tensor([[0.3039]], device='cuda:0')
# Class activation mapping results grid lines added
# 9
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/741/Figure_4.png
# 0.2667795717716217
# Archivo: 741.pdf, Figura: Figure_4, Label: nan, Similaridad: tensor([[0.2668]], device='cuda:0')
# Class activation mapping results piece appearance changed
# 9
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/741/Figure_5.png
# 0.25659406185150146
# Archivo: 741.pdf, Figura: Figure_5, Label: nan, Similaridad: tensor([[0.2566]], device='cuda:0')
# Class activation mapping results true positive samples 500 iterations left 5313 accuracy 1000 iterations right 100 accuracy
# 28
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/741/Figure_6.png
# 0.2732243239879608
# Archivo: 741.pdf, Figura: Figure_6, Label: nan, Similaridad: tensor([[0.2732]], device='cuda:0')
# propose two quantitative evaluation protocols selecting activated patch calculate frequent representation fire correct location b correlate representation ideal activation map
# 21
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/741/Figure_7.png
# 0.2525639832019806
# Archivo: 741.pdf, Figura: Figure_7, Label: nan, Similaridad: tensor([[0.2526]], device='cuda:0')
# Quantitative results
# 4
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/741/Table_1.png
# 0.25875023007392883
# Archivo: 741.pdf, Figura: Table_1, Label: nan, Similaridad: tensor([[0.2588]], device='cuda:0')
# exponential growth trajectory length depth random deep network hardtanh nonlinearities circular trajectory chosen two random vectors image trajectory taken layer network length measured ab trajectory length vs layer terms network width k weight variance determine growth rate cd average ratio trajectory length layer 1 relative length layer solid line shows simulated data dashed lines show upper lower bounds Growth rate function layer width k weight variance
# 53
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/742/Figure_1.png
# 0.30152109265327454
# Archivo: 742.pdf, Figura: Figure_1, Label: nan, Similaridad: tensor([[0.3015]], device='cuda:0')
# number transitions linear trajectory length compare empirical number sign changes length trajectory images trajectory different layers hardtanh network repeat comparison variety network architectures different network width k weight variance
# 29
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/742/Figure_2.png
# 0.3039010763168335
# Archivo: 742.pdf, Figura: Figure_2, Label: nan, Similaridad: tensor([[0.3039]], device='cuda:0')
# Deep networks piecewise linear activations subdivide input space convex poly topes plot boundaries input space separating unit activation inactivation units three layer ReLU network four units layer left pane shows activation boundaries corresponding hyperplane arrangement gray first layer partitioning plane regions center pane shows activation boundaries first two layers Inside every first layer region second layer activation boundaries form different hyperplane arrange ment right pane shows activation boundaries first three layers different hyperplane arrangements inside first second layer regions final set convex regions correspond different activation patterns network ie different linear functions
# 67
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/742/Figure_3.png
# 0.2970908582210541
# Archivo: 742.pdf, Figura: Figure_3, Label: nan, Similaridad: tensor([[0.2971]], device='cuda:0')
# number functions achievable deep hardtanh network sweeping single layer weights along one dimensional trajectory exponential remaining depth creases slowly network width plot number classification dichotomies 15 input vectors achieved sweeping first layer weights hardtanh network along onedimensional great circle trajectory show function remaining depth several widths b function width several remaining depths networks generated weight variance 8 bias variance 0
# 57
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/742/Figure_4.png
# 0.2769145369529724
# Archivo: 742.pdf, Figura: Figure_4, Label: nan, Similaridad: tensor([[0.2769]], device='cuda:0')
# Expressive power depends remaining network depth plot number dichotomies achieved sweeping weights different network layers 1dimensional great circle trajectory function remaining network depth number achievable dichotomies depend total network depth number layers layer swept networks width k 128 weight variance 8 number datapoints 15 hardtanh nonlinearities blue dashed line indicates 2 possible dichotomies random dataset
# 59
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/742/Figure_5.png
# 0.29612043499946594
# Archivo: 742.pdf, Figura: Figure_5, Label: nan, Similaridad: tensor([[0.2961]], device='cuda:0')
# Demonstration expressive power remaining depth MNIST plot train test accuracy achieved training exactly one layer fully connected neural net MNIST different lines generated varying hidden layer chosen train layers kept frozen random initialization see training lower hidden layers leads better performance networks width k 100 weight variance 2 hardtanh nonlin earities Note train second hidden layer weights W onwards number parameters trained remains fixed theory addresses training accuracy generalization accuracy monotonic pattern seen
# 71
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/742/Figure_6.png
# 0.28725120425224304
# Archivo: 742.pdf, Figura: Figure_6, Label: nan, Similaridad: tensor([[0.2873]], device='cuda:0')
# repeat similar experiment Figure6with fully connected network CIFAR10 mostly observe training lower layers leads better performance networks width k 200 weight variance 1 hardtanh nonlinearities train second hidden layer number parameters remains fixed
# 45
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/742/Figure_7.png
# 0.277035117149353
# Archivo: 742.pdf, Figura: Figure_7, Label: nan, Similaridad: tensor([[0.2770]], device='cuda:0')
# List location key theoretical experimental results
# 8
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/742/Table_1.png
# 0.30001911520957947
# Archivo: 742.pdf, Figura: Table_1, Label: nan, Similaridad: tensor([[0.3000]], device='cuda:0')
# Training acts stabilize inputoutput map decreasing trajectory length oy large left pane plots growth trajectory length circular interpolation two MNIST datapoints propagated network different train steps Red indicates start training purple end training Interestingly supporting observation remaining depth first layer appears increase trajectory length contrast later layers suggesting primarily used fit data right pane shows identical plot interpolation random points also display decreasing trajectory length slower rate Note output layer plotted due artificial scaling length normalization
# 77
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/742/Figure_8.png
# 0.31464606523513794
# Archivo: 742.pdf, Figura: Figure_8, Label: nan, Similaridad: tensor([[0.3146]], device='cuda:0')
# Training increases expressivity inputoutput map small left pane plots growth trajectory length circular interpolation two MNIST datapoints propagated network different train steps Red indicates start training purple end training see training process increases trajectory length likely increase expressivity inputoutput map enable greater accuracy right pane shows identical plot interpolation random points also displays increasing trajectory length slower rate Note output layer plotted due artificial scaling length normalization network initialized 3
# 69
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/742/Figure_9.png
# 0.3096621632575989
# Archivo: 742.pdf, Figura: Figure_9, Label: nan, Similaridad: tensor([[0.3097]], device='cuda:0')
# plot number unique dichotomies observed function number transitions network undergone datapoint corresponds number transitions dichotomies hardtanh network different depth weights first layer undergoing interpolation along great circle trajectory W compare plots random walk simulation transition single class label flipped uniformly random Dichotomies measured dataset consisting 15 random samples networks weight variance 16 blue dashed line indicates 2 possible dichotomies
# 69
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/742/Figure_10.png
# 0.2996519207954407
# Archivo: 742.pdf, Figura: Figure_10, Label: nan, Similaridad: tensor([[0.2997]], device='cuda:0')
# identical plot Figure8but transition count
# 9
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/742/Figure_11.png
# 0.2944464385509491
# Archivo: 742.pdf, Figura: Figure_11, Label: nan, Similaridad: tensor([[0.2944]], device='cuda:0')
# repeat experiment Figure 6 convolutional network trained CIFAR 10 network eight convolutional hidden layers three three filters 64 filters layer ReLU activations final layer fully connected softmax trained addition single convolutional layer trained results support greater expressive power remaining depth Note final three convolutional layers failed effectively train performed chance level
# 47
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/742/Figure_12.png
# 0.2643609941005707
# Archivo: 742.pdf, Figura: Figure_12, Label: nan, Similaridad: tensor([[0.2644]], device='cuda:0')
# Search times randomly selected words two ensembles compared curve fc inBakhtin Correll estimated decision times experiment
# 22
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/743/Figure_1.png
# 0.33206143975257874
# Archivo: 743.pdf, Figura: Figure_1, Label: nan, Similaridad: tensor([[0.3321]], device='cuda:0')
# Empirical histograms halting time fluctuations TvQR2 N 150 10 various choices ensembles E figure shows four normalized histograms one E GOE GUE QUE clear fluctuations follow universal law
# 37
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/743/Figure_2.png
# 0.29846271872520447
# Archivo: 743.pdf, Figura: Figure_2, Label: nan, Similaridad: tensor([[0.2985]], device='cuda:0')
# Empirical histograms halting time fluctuations 7cg2 N 500 101 various choices ensembles E scaling N 2N demonstrating presence universality plot shows three histograms one E LUE LOE PBE b scaling 14 N showing two histograms E LUE LOE demonstrating nonexistence universality
# 45
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/743/Figure_3.png
# 0.31314176321029663
# Archivo: 743.pdf, Figura: Figure_3, Label: nan, Similaridad: tensor([[0.3131]], device='cuda:0')
# Universality across different distributions choose Gaussian0 1 uniform 323 323 Bernoulli 12 equal probability
# 23
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/743/Figure_4.png
# 0.2970712184906006
# Archivo: 743.pdf, Figura: Figure_4, Label: nan, Similaridad: tensor([[0.2971]], device='cuda:0')
# Universality halting time deep learning cost functions MNIST digit inputs independent Gaussian noise inputs give rise halting time fluctuations well convnet different stopping condition
# 30
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/743/Figure_5.png
# 0.29394829273223877
# Archivo: 743.pdf, Figura: Figure_5, Label: nan, Similaridad: tensor([[0.2939]], device='cuda:0')
# consecutive costs MNIST varies 06 0005
# 13
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/743/Figure_6.png
# 0.27058181166648865
# Archivo: 743.pdf, Figura: Figure_6, Label: nan, Similaridad: tensor([[0.2706]], device='cuda:0')
# Skewness 3rd moment kurtosis 4th moment experiments 1
# 14
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/743/Table_1.png
# 0.25593751668930054
# Archivo: 743.pdf, Figura: Table_1, Label: nan, Similaridad: tensor([[0.2559]], device='cuda:0')
# Gating mechanism applied shortcut connection layer key difference Highway Networks scalar k used regulate gates instead tensor
# 21
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/744/Figure_1.png
# 0.27982476353645325
# Archivo: 744.pdf, Figura: Figure_1, Label: nan, Similaridad: tensor([[0.2798]], device='cuda:0')
# Proposed network design applied Residual Networks Note joint network design results shortcut path input remains unchanged case gk interpreted amplifier suppressor residual fx W
# 25
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/744/Figure_2.png
# 0.25797319412231445
# Archivo: 744.pdf, Figura: Figure_2, Label: nan, Similaridad: tensor([[0.2580]], device='cuda:0')
# network layers added without losing performance Initially network ReLU layers parameters W1 Wm new 1th layer added W41 new layer perform identity mapping therefore two models equivalent
# 29
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/744/Figure_3.png
# 0.2663699984550476
# Archivo: 744.pdf, Figura: Figure_3, Label: nan, Similaridad: tensor([[0.2664]], device='cuda:0')
# Train loss plain residual networks along augmented counterparts 210 2050 100 models get deeper error reduction due augmentation increases
# 30
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/744/Figure_4.png
# 0.2443358302116394
# Archivo: 744.pdf, Figura: Figure_4, Label: nan, Similaridad: tensor([[0.2443]], device='cuda:0')
# Test error MNIST dataset fullyconnected networks Augmented models outperform original counterparts experiments Nonaugmented plain networks perform worse fail converge 50 100
# 31
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/744/Table_1.png
# 0.3113337457180023
# Archivo: 744.pdf, Figura: Table_1, Label: nan, Similaridad: tensor([[0.3113]], device='cuda:0')
# Mean k increasingly deep Gated PlainNets Gated ResNets
# 11
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/744/Table_2.png
# 0.30795902013778687
# Archivo: 744.pdf, Figura: Table_2, Label: nan, Similaridad: tensor([[0.3080]], device='cuda:0')
# Left Values k according ascending order residual blocks first block consisted first two layers network index 1 last block right softmax layer index 50 Right Test accuracy according number removed layers Gated Residual Networks robust layer removal maintain decent results even half layers removed
# 38
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/744/Figure_5.png
# 0.26909899711608887
# Archivo: 744.pdf, Figura: Figure_5, Label: nan, Similaridad: tensor([[0.2691]], device='cuda:0')
# Test error CIFAR10 dataset ResNets Wide ResNets augmented counterparts k decay weight decay also applied parameters augmented
# 21
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/744/Table_3.png
# 0.2671065628528595
# Archivo: 744.pdf, Figura: Table_3, Label: nan, Similaridad: tensor([[0.2671]], device='cuda:0')
# Test error CIFAR10 dataset Wide ResNets augmented counter
# 16
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/744/Table_4.png
# 0.24739663302898407
# Archivo: 744.pdf, Figura: Table_4, Label: nan, Similaridad: tensor([[0.2474]], device='cuda:0')
# Test error CIFAR100 dataset Wide ResNets augmented counter
# 17
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/744/Table_5.png
# 0.2433614581823349
# Archivo: 744.pdf, Figura: Table_5, Label: nan, Similaridad: tensor([[0.2434]], device='cuda:0')
# Values k according ascending order residual blocks first block consisted
# 13
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/744/Figure_6.png
# 0.3274866044521332
# Archivo: 744.pdf, Figura: Figure_6, Label: nan, Similaridad: tensor([[0.3275]], device='cuda:0')
# Training test curves Wide ResNet 410 03 dropout showing error
# 17
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/744/Figure_7.png
# 0.3118739724159241
# Archivo: 744.pdf, Figura: Figure_7, Label: nan, Similaridad: tensor([[0.3119]], device='cuda:0')
# Test error CIFAR10 CIFAR100 dataset results standard data
# 18
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/744/Table_6.png
# 0.2523135244846344
# Archivo: 744.pdf, Figura: Table_6, Label: nan, Similaridad: tensor([[0.2523]], device='cuda:0')
# Instantiation Dynamic Programming Net input instance recurrently split smaller instances reach critical scale merge procedure works opposite direction highlight fact split merge sizes vary data dependent therefore binary tree sampledependent split blocks share parameters 0 similarly merge blocks
# 41
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/746/Figure_1.png
# 0.2778434455394745
# Archivo: 746.pdf, Figura: Figure_1, Label: nan, Similaridad: tensor([[0.2778]], device='cuda:0')
# b loss every scale computed averaging losses nodes elements batch show first 6 scales input distribution every node generated tree different every block scale inputs given scale result finer partition inputs previous one Losses training data set N05 025 observe values losses similar However losses first scales little bit larger others input distribution becomes symmetric partition gets finer b Losses training data set Expw 01 training using exponential distribution mean 1 01 input observe due high nonsymmetry losses first scale larger value However difference losses shrinks training c following tests performed architecture trained using normal distribution points computed averaging 100 examples c Inversions Ratio IR generalization test results impressive test n 100 ton 14000 accuracy converges value magnitude 10 10 curve beginning test means number inversions 0 results show model performs better input distribution normal resulting input distributions every block easier split equal parts Without regularization results worse Average depths plot average depths generated tree depth logarithmic respect size input curve independent test distribution regularization term key make complexity algorithm close optimal
# 135
# 69
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/746/Figure_2.png
# 69
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/746/Figure_2.png
# 0.3018694818019867
# Archivo: 746.pdf, Figura: Figure_2, Label: nan, Similaridad: tensor([[0.3019]], device='cuda:0')
# every epoch test model dataset size 128 Test accuracies observe accuracy lower 3 scales due tree structure errors propagate case SS merge block able correct mistakes coming previous layers model always trained correct inputs WS also observe lower accuracy 3 scales however decrease smaller using strong supervision claim reason block able correct mistakes previous layers inputs blocks training perfect convex hulls also show without regularization model able learn WS b Analysis ay plot average number masked elements every scale batch size 16 theoretical masks computed using correct dynamic algorithm estimate masks ones computed using prior ay used training experimental corresponds masks forward pass using trained model c Examples test time WS two examples show model able correct mistakes previous scales producing output convex hull good accuracy
# 94
# 49
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/746/Figure_3.png
# 48
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/746/Figure_3.png
# 0.24437358975410461
# Archivo: 746.pdf, Figura: Figure_3, Label: nan, Similaridad: tensor([[0.2444]], device='cuda:0')
# Pixel importance using gradients image
# 9
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/747/Figure_1.png
# 0.27271217107772827
# Archivo: 747.pdf, Figura: Figure_1, Label: nan, Similaridad: tensor([[0.2727]], device='cuda:0')
# Saturation Inception
# 5
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/747/Figure_2.png
# 0.22293059527873993
# Archivo: 747.pdf, Figura: Figure_2, Label: nan, Similaridad: tensor([[0.2229]], device='cuda:0')
# Visualization interior gradients Notice visualizations lower values scaling parameter sharper much better surfacing important features input image
# 26
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/747/Figure_3.png
# 0.2754528522491455
# Archivo: 747.pdf, Figura: Figure_3, Label: nan, Similaridad: tensor([[0.2755]], device='cuda:0')
# Comparing integrated gradients gradients image Lefttoright original input image label softmax score highest scoring class visualization integrated gradi ents visualization gradients image Notice visualizations obtained integrated gradients better reflecting distinctive features image
# 33
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/747/Figure_4.png
# 0.3045006990432739
# Archivo: 747.pdf, Figura: Figure_4, Label: nan, Similaridad: tensor([[0.3045]], device='cuda:0')
# AOPC Samek et al2015 integrated gradients gradients image
# 18
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/747/Figure_5.png
# 0.22105801105499268
# Archivo: 747.pdf, Figura: Figure_5, Label: nan, Similaridad: tensor([[0.2211]], device='cuda:0')
# Interior gradients misclassified images Lefttoright Original image Softmax score top label assigned Inception network groundtruth label provided ImageNet visualization integrated gradients wrt Inception label visualization integrated gradients wrt groundtruth label
# 32
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/747/Figure_6.png
# 0.3096029758453369
# Archivo: 747.pdf, Figura: Figure_6, Label: nan, Similaridad: tensor([[0.3096]], device='cuda:0')
# Attribution molecule W2N2 network
# 10
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/747/Figure_7.png
# 0.27191361784935
# Archivo: 747.pdf, Figura: Figure_7, Label: nan, Similaridad: tensor([[0.2719]], device='cuda:0')
# Softmax scores next word LSTM language model Section32
# 14
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/747/Figure_8.png
# 0.3138866424560547
# Archivo: 747.pdf, Figura: Figure_8, Label: nan, Similaridad: tensor([[0.3139]], device='cuda:0')
# Prediction 05307 total integrated gradient 05322
# 16
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/747/Figure_9.png
# 0.23411397635936737
# Archivo: 747.pdf, Figura: Figure_9, Label: nan, Similaridad: tensor([[0.2341]], device='cuda:0')
# Prediction ual 00062 total integrated gradient 00063
# 17
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/747/Figure_10.png
# 0.2131136804819107
# Archivo: 747.pdf, Figura: Figure_10, Label: nan, Similaridad: tensor([[0.2131]], device='cuda:0')
# visualizations comparing integrated gradients gradients image Lefttoright original input image label softmax score highest scoring class visualiza tion integrated gradients visualization gradients image
# 28
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/747/Figure_11.png
# 0.2738896310329437
# Archivo: 747.pdf, Figura: Figure_11, Label: nan, Similaridad: tensor([[0.2739]], device='cuda:0')
# Saturation intermediate layers Inception layer plot L2 Cosine distance activation vector scaled image actual input image respect scaling parameter plot shows trend 30 randomly chosen images ImageNet dataset Notice trends plots flatten scaling parameter increases deepest Inception layer mixed5b Cosine distance activation vector image less 001 06 really tiny given layer 50176 neurons
# 61
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/747/Figure_12.png
# 0.30043625831604004
# Archivo: 747.pdf, Figura: Figure_12, Label: nan, Similaridad: tensor([[0.3004]], device='cuda:0')
# Saturation W2N2 network Kearnes et al2016 Plots softmax score e gradients wrt
# 26
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/747/Figure_13.png
# 0.28099343180656433
# Archivo: 747.pdf, Figura: Figure_13, Label: nan, Similaridad: tensor([[0.2810]], device='cuda:0')
# Attributions two functionally equivalent networks figure shows attributions two functionally equivalent networks f 2122 ga1 22 input 7 3 v2 1 using integrated gradients DeepLift Shrikumar et al 2016 Layerwise relevance propa gation LRP 2016 reference input Integrated gradients DeepLift x 0 x2 0 methods except integrated gradients provide different attributions two networks
# 53
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/747/Figure_14.png
# 0.33238816261291504
# Archivo: 747.pdf, Figura: Figure_14, Label: nan, Similaridad: tensor([[0.3324]], device='cuda:0')
# Neural machine translation model singlelayer convolutional encoder networks CNNa left CNNc right Embedding layers shown
# 24
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/748/Figure_1.png
# 0.30985400080680847
# Archivo: 748.pdf, Figura: Figure_1, Label: nan, Similaridad: tensor([[0.3099]], device='cuda:0')
# Accuracy encoders position features words pos without words terms BLEU perplexity PPL IWSLT 14 German English translation results include unknown word replacement Deep Convolutional 63 multilayer configuration layers LSTMs improve accuracy dataset
# 45
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/748/Table_1.png
# 0.2998509109020233
# Archivo: 748.pdf, Figura: Table_1, Label: nan, Similaridad: tensor([[0.2999]], device='cuda:0')
# Accuracy three WMT tasks including results published previous work deep convolutional encoders include number layers CNNa CNNc respectively
# 27
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/748/Table_2.png
# 0.27035048604011536
# Archivo: 748.pdf, Figura: Table_2, Label: nan, Similaridad: tensor([[0.2704]], device='cuda:0')
# Effect encoder depth IWSLT 14 without residual connections xaxis varies number layers CNNa curves show different CNNc settings
# 27
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/748/Figure_2.png
# 0.3022548258304596
# Archivo: 748.pdf, Figura: Figure_2, Label: nan, Similaridad: tensor([[0.3023]], device='cuda:0')
# Generation speed source words per second single CPU core
# 11
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/748/Table_3.png
# 0.3020152747631073
# Archivo: 748.pdf, Figura: Table_3, Label: nan, Similaridad: tensor([[0.3020]], device='cuda:0')
# BLEU per sentence length WMT 15 EnglishGerman newstest2015 test set partitioned 15 equallysized buckets according source sentence length
# 29
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/748/Figure_3.png
# 0.30050697922706604
# Archivo: 748.pdf, Figura: Figure_3, Label: nan, Similaridad: tensor([[0.3005]], device='cuda:0')
# Attention scores WMT 15 EnglishGerman translation sentence newstest2015
# 18
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/748/Figure_4.png
# 0.18170616030693054
# Archivo: 748.pdf, Figura: Figure_4, Label: nan, Similaridad: tensor([[0.1817]], device='cuda:0')
# Attention scores WMT 14 EnglishFrench translation sentence ntst4
# 15
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/748/Figure_5.png
# 0.18645712733268738
# Archivo: 748.pdf, Figura: Figure_5, Label: nan, Similaridad: tensor([[0.1865]], device='cuda:0')
# Case 1 empirical study XOR classification task left figure network structure use h linear transformation hz nonlinear transform h prediction right column linear transformation maps x hy shown red arrow Lz norm penalty hz centers feature h make points different sets separable X refer positive examples negative ones
# 45
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/750/Figure_1.png
# 0.24696174263954163
# Archivo: 750.pdf, Figura: Figure_1, Label: nan, Similaridad: tensor([[0.2470]], device='cuda:0')
# Case 2 comprehensive study twolayer linear neural network regression task minimize Lz distance prediction 7 W2W x bi latent representation h W x linear mapping
# 24
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/750/Figure_2.png
# 0.2318832129240036
# Archivo: 750.pdf, Figura: Figure_2, Label: nan, Similaridad: tensor([[0.2319]], device='cuda:0')
# Evaluation XOR classification task red blue green lines stand accuracy Neural Network without regularization L feature penalty model weight feature regularizer respectively
# 27
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/750/Figure_3.png
# 0.29907864332199097
# Archivo: 750.pdf, Figura: Figure_3, Label: nan, Similaridad: tensor([[0.2991]], device='cuda:0')
# Experimental results algorithm Omniglot benchmark Lake et al 2011
# 16
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/750/Table_1.png
# 0.31941357254981995
# Archivo: 750.pdf, Figura: Table_1, Label: nan, Similaridad: tensor([[0.3194]], device='cuda:0')
# Experimental results algorithm ImageNet benchmark Russakovsky et al 2015 20way oneshot setting
# 25
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/750/Table_2.png
# 0.2750987112522125
# Archivo: 750.pdf, Figura: Table_2, Label: nan, Similaridad: tensor([[0.2751]], device='cuda:0')
# Classification accuracy comparison feature penalty termed PN batch
# 11
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/750/Figure_4.png
# 0.2706119418144226
# Archivo: 750.pdf, Figura: Figure_4, Label: nan, Similaridad: tensor([[0.2706]], device='cuda:0')
# typical deep reinforcement learning techniques agent may forget catastrophic failure modes become unlikely updated policy intrinsic fear learn recognize danger zones red circles around catastrophes shape reward functions away zones
# 37
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/751/Figure_1.png
# 0.2870778441429138
# Archivo: 751.pdf, Figura: Figure_1, Label: nan, Similaridad: tensor([[0.2871]], device='cuda:0')
# experiments consider two toy environments ab Atari game Seaquest c
# 12
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/751/Figure_2.png
# 0.22443827986717224
# Archivo: 751.pdf, Figura: Figure_2, Label: nan, Similaridad: tensor([[0.2244]], device='cuda:0')
# Total catastrophes total reward DQNs ESARSA variant Intrinsic Fear DQNs Adventure Seeker CartPole Atari game Seaquest results Cart Pole averaged 5 runs Atari results averaged 3 runs Adventure Seeker Intrinsic Fear models achieve immortality within 14 runs giving unbounded total reward 0 catastrophes thereafter Seaquest fear factor setting 10 model achieves nearidentical catastrophe rate significantly higher total reward
# 57
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/751/Figure_3.png
# 0.24407973885536194
# Archivo: 751.pdf, Figura: Figure_3, Label: nan, Similaridad: tensor([[0.2441]], device='cuda:0')
# Sparse pointer network code suggestion Python code snippet showing next word distributions language model identifier attention weighted combination
# 22
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/754/Figure_1.png
# 0.2640044093132019
# Archivo: 754.pdf, Figura: Figure_1, Label: nan, Similaridad: tensor([[0.2640]], device='cuda:0')
# Python corpus statistics
# 5
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/754/Table_1.png
# 0.276871919631958
# Archivo: 754.pdf, Figura: Table_1, Label: nan, Similaridad: tensor([[0.2769]], device='cuda:0')
# Example Python code normalization Original file left normalized version right
# 14
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/754/Figure_2.png
# 0.26832330226898193
# Archivo: 754.pdf, Figura: Figure_2, Label: nan, Similaridad: tensor([[0.2683]], device='cuda:0')
# Perplexity PP Accuracy Acc Accuarcy among top 5 predictions Acc5
# 16
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/754/Table_2.png
# 0.2956138253211975
# Archivo: 754.pdf, Figura: Table_2, Label: nan, Similaridad: tensor([[0.2956]], device='cuda:0')
# Code suggestion example involving reference variable ad longrange dependency eh attention weights Sparse Pointer Network
# 20
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/754/Figure_3.png
# 0.2830093204975128
# Archivo: 754.pdf, Figura: Figure_3, Label: nan, Similaridad: tensor([[0.2830]], device='cuda:0')
# Full example code suggestion Sparse Pointer Network Boldface tokens left show first declaration identifier middle part visualizes memory representations identifiers right part visualizes output controller used interpolating
# 35
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/754/Figure_4.png
# 0.2574615180492401
# Archivo: 754.pdf, Figura: Figure_4, Label: nan, Similaridad: tensor([[0.2575]], device='cuda:0')
# example different position nonlinearities residual unit 2shortcut net work
# 16
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/755/Figure_1.png
# 0.23018179833889008
# Archivo: 755.pdf, Figura: Figure_1, Label: nan, Similaridad: tensor([[0.2302]], device='cuda:0')
# average Frobenius norms ResNets different depths training process preResNet implementation injhttpsgithubcomfacebookfbresnettorch used learning rate initialized 01 decreased 001 81 epoch marked circles decreased 0001 122 epoch marked triangles model trained 200 epochs 3s 4 af seome2 35 ae 3 28 mM os 5 co z Hips NA 32 815 b dopin Eg 8 B15 cop t6 aR aay 5 tenes Sy devin mn TB yf opth 128 TEE Fy 9 05 F depth 256 Tag 05 25 3 25 245 4 os log oloss loss log gloss NEW
# 129
# 49
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/755/Figure_2.png
# 82
# 44
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/755/Figure_2.png
# 40
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/755/Figure_2.png
# 0.23361089825630188
# Archivo: 755.pdf, Figura: Figure_2, Label: nan, Similaridad: tensor([[0.2336]], device='cuda:0')
# average Frobenius norms 2shortcut networks different depths training process zero initialized Left Without nonlinearities Right ReLUs mid positions
# 28
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/755/Figure_3.png
# 0.24710816144943237
# Archivo: 755.pdf, Figura: Figure_3, Label: nan, Similaridad: tensor([[0.2471]], device='cuda:0')
# Equivalents two extremes nshortcut linear networks 1shortcut linear networks
# 16
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/755/Figure_4.png
# 0.2765515446662903
# Archivo: 755.pdf, Figura: Figure_4, Label: nan, Similaridad: tensor([[0.2766]], device='cuda:0')
# Initial condition numbers Hessians different linear networks depths networks increase Means standard deviations estimated based 10 runs
# 22
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/755/Figure_5.png
# 0.2361603081226349
# Archivo: 755.pdf, Figura: Figure_5, Label: nan, Similaridad: tensor([[0.2362]], device='cuda:0')
# Maxima 10 percentiles absolute values eigenvalues different losses depth 16 run eigenvalues different losses calculated using linear interpolation
# 26
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/755/Figure_6.png
# 0.2835536003112793
# Archivo: 755.pdf, Figura: Figure_6, Label: nan, Similaridad: tensor([[0.2836]], device='cuda:0')
# Maxima 10 percentiles absolute values eigenvalues different losses depth 16 Eigenvalues different losses calculated using linear interpolation
# 25
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/755/Figure_7.png
# 0.2755793631076813
# Archivo: 755.pdf, Figura: Figure_7, Label: nan, Similaridad: tensor([[0.2756]], device='cuda:0')
# Left ratio negative eigenvalues different losses depth 16 run indexes different losses calculated using linear interpolation Right dynamics gradient index 2shortcut linear network single run gradient reaches maximum index drops dramatically indicating moving toward negative curvature directions
# 43
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/755/Figure_8.png
# 0.2664793133735657
# Archivo: 755.pdf, Figura: Figure_8, Label: nan, Similaridad: tensor([[0.2665]], device='cuda:0')
# Left Optimal Final losses different linear networks Right Corresponding optimal learning rates depth 96 final losses Xavier different learning rates basically optimal learning rate omitted unstable
# 23
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/755/Figure_9.png
# 0.26923027634620667
# Archivo: 755.pdf, Figura: Figure_9, Label: nan, Similaridad: tensor([[0.2692]], device='cuda:0')
# Left Optimal Final losses different networks ReLUs mid positions Right Corresponding optimal learning rates Note hard compute minimum losses ReLUs plot log final loss instead log final loss optimal loss depth 64 final losses XavierReLU orthogonalReLU different learning rates basically optimal learning rates omitted unstable
# 41
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/train/755/Figure_10.png
# 0.3023597002029419
# Archivo: 755.pdf, Figura: Figure_10, Label: nan, Similaridad: tensor([[0.3024]], device='cuda:0')
# ...
# 57
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/728/Figure 2.png
# 0.2751118540763855
# Archivo: 728.pdf, Figura: Figure 2, Label: 0.0, Similaridad: tensor([[0.2751]], device='cuda:0')
# SAMDP visualization Breakout MDP state represented map two tSNE coordinates colored value estimate low values blue high red SAMDP states visualized mean state frame pixels mean tSNE coordinate Edge two SAMDP states represents skill bold side indicate terminal state numbers edges correspond inferred SAMDP policy
# 45
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/728/Figure 3.png
# 0.2830406427383423
# Archivo: 728.pdf, Figura: Figure 3, Label: 0.0, Similaridad: tensor([[0.2830]], device='cuda:0')
# Model Evaluation Top VMSE Center greedy policy correlation trajectory reward Bottom top blue least red rewarded trajectories
# 21
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/728/Figure 4.png
# 0.32741761207580566
# Archivo: 728.pdf, Figura: Figure 4, Label: 0.0, Similaridad: tensor([[0.3274]], device='cuda:0')
# Distributed Bag Words version paragraph vectors paragraph vector used predict words small window cat sat
# 16
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/732/Figure 1.png
# 0.27539801597595215
# Archivo: 732.pdf, Figura: Figure 1, Label: 0.0, Similaridad: tensor([[0.2754]], device='cuda:0')
# Left graphical model representation Generative Paragraph Vector GPV boxes plates representing replicates shaded node observed variable unshaded node hidden variable Right Graphical model representation Supervised Generative Paragraph Vector SGPV
# 27
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/732/Figure 2.png
# 0.28072431683540344
# Archivo: 732.pdf, Figura: Figure 2, Label: 0.0, Similaridad: tensor([[0.2807]], device='cuda:0')
# Performance Comparison Unsupervised Representation Models
# 8
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/732/Table 1.png
# 0.29878684878349304
# Archivo: 732.pdf, Figura: Table 1, Label: 0.0, Similaridad: tensor([[0.2988]], device='cuda:0')
# Performance Comparison Supervised Representation Models
# 7
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/732/Table 2.png
# 0.29771000146865845
# Archivo: 732.pdf, Figura: Table 2, Label: 0.0, Similaridad: tensor([[0.2977]], device='cuda:0')
# Overview proposed method
# 5
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/733/Figure 1.png
# 0.29408693313598633
# Archivo: 733.pdf, Figura: Figure 1, Label: 0.0, Similaridad: tensor([[0.2941]], device='cuda:0')
# Systemcall language model
# 7
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/733/Figure 2.png
# 0.270444393157959
# Archivo: 733.pdf, Figura: Figure 2, Label: 0.0, Similaridad: tensor([[0.2704]], device='cuda:0')
# Summary datasets used experiments
# 7
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/733/Table 1.png
# 0.2778305113315582
# Archivo: 733.pdf, Figura: Table 1, Label: 0.0, Similaridad: tensor([[0.2778]], device='cuda:0')
# ROC curves ADFALD Left shows result three systemcall language models different parameters two baseline classifiers Right illustrates results different ensemble methods
# 27
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/733/Figure 3.png
# 0.31705915927886963
# Archivo: 733.pdf, Figura: Figure 3, Label: 0.0, Similaridad: tensor([[0.3171]], device='cuda:0')
# ROC curves KDD dataset UNM dataset Left evaluation KDD dataset Right evaluation UNM dataset using model trained KDD98 dataset UNM dataset
# 20
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/733/Figure 4.png
# 0.35154974460601807
# Archivo: 733.pdf, Figura: Figure 4, Label: 0.0, Similaridad: tensor([[0.3515]], device='cuda:0')
# 2D embedding learned call representations shows full representation space system calls appeared training data b c show zoomedin view specific regions
# 26
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/733/Figure 5.png
# 0.285982221364975
# Archivo: 733.pdf, Figura: Figure 5, Label: 0.0, Similaridad: tensor([[0.2860]], device='cuda:0')
# Left Probabilistic interpretation CCA Bach Jordan 2005 Right deep variational CCA VCCA model
# 21
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/734/Figure 1.png
# 0.3032064139842987
# Archivo: 734.pdf, Figura: Figure 1, Label: 0.0, Similaridad: tensor([[0.3032]], device='cuda:0')
# VCCAprivate variational CCA viewspecific private variables
# 14
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/734/Figure 2.png
# 0.2653430998325348
# Archivo: 734.pdf, Figura: Figure 2, Label: 0.0, Similaridad: tensor([[0.2653]], device='cuda:0')
# Left Selection view 1 images top corresponding view 2 images bottom noisy MNIST Right 2D tSNE visualization features learned previous multiview models
# 25
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/734/Figure 3.png
# 0.2857610583305359
# Archivo: 734.pdf, Figura: Figure 3, Label: 0.0, Similaridad: tensor([[0.2858]], device='cuda:0')
# 2D tSNE embeddings extracted shared variables z test set VCCA top row VCCAprivate bottom row different dropout rates dz 40 algorithms
# 32
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/734/Figure 4.png
# 0.28037670254707336
# Archivo: 734.pdf, Figura: Figure 4, Label: 0.0, Similaridad: tensor([[0.2804]], device='cuda:0')
# Sample reconstruction view 2 images test set VCCA VCCAprivate
# 14
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/734/Figure 5.png
# 0.28375300765037537
# Archivo: 734.pdf, Figura: Figure 5, Label: 0.0, Similaridad: tensor([[0.2838]], device='cuda:0')
# Performance features extracted different methods downstream tasks Classification error rates linear SVMs MNIST mean phone error rate PER 6 folds XRMB mean average precision mAP unimodal retrieval MIRFlickr
# 34
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/734/Table 1.png
# 0.290260910987854
# Archivo: 734.pdf, Figura: Table 1, Label: 0.0, Similaridad: tensor([[0.2903]], device='cuda:0')
# 2D tSNE embedding shared variables z R 40 top private variables hx R 30 bottom
# 20
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/734/Figure 6.png
# 0.29880282282829285
# Archivo: 734.pdf, Figura: Figure 6, Label: 0.0, Similaridad: tensor([[0.2988]], device='cuda:0')
# Basic LSTM cell
# 6
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/738/Figure 1.png
# 0.3029364347457886
# Archivo: 738.pdf, Figura: Figure 1, Label: 0.0, Similaridad: tensor([[0.3029]], device='cuda:0')
# Values gates new cell activations LSTM three sigmoidbased gates range xaxis 0 1 tanhbased new cell activation range 1 1
# 22
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/738/Figure 2.png
# 0.26497894525527954
# Archivo: 738.pdf, Figura: Figure 2, Label: 0.0, Similaridad: tensor([[0.2650]], device='cuda:0')
# Impact Training Sparsified SGD
# 9
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/738/Figure 3.png
# 0.20349162817001343
# Archivo: 738.pdf, Figura: Figure 3, Label: 0.0, Similaridad: tensor([[0.2035]], device='cuda:0')
# Sparsity dnet different thresholds
# 9
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/738/Figure 4.png
# 0.2929517328739166
# Archivo: 738.pdf, Figura: Figure 4, Label: 0.0, Similaridad: tensor([[0.2930]], device='cuda:0')
# Validation Loss different thresholds
# 7
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/738/Figure 5.png
# 0.24909096956253052
# Archivo: 738.pdf, Figura: Figure 5, Label: 0.0, Similaridad: tensor([[0.2491]], device='cuda:0')
# Actuation models respective actuator parameters
# 9
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/775/Table 1.png
# 0.2989819645881653
# Archivo: 775.pdf, Figura: Table 1, Label: 0.0, Similaridad: tensor([[0.2990]], device='cuda:0')
# Simulated articulated figures state representation Revolute joints connect links left right 7link biped 19link raptor 21link dog State features root height relative position red link respect root respective linear velocity green
# 39
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/775/Figure 1.png
# 0.3119739294052124
# Archivo: 775.pdf, Figura: Figure 1, Label: 0.0, Similaridad: tensor([[0.3120]], device='cuda:0')
# Learning curves policy 1 million iterations
# 8
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/775/Figure 2.png
# 0.25300073623657227
# Archivo: 775.pdf, Figura: Figure 2, Label: 0.0, Similaridad: tensor([[0.2530]], device='cuda:0')
# Performance subjected random perturbation forces different magnitudes
# 13
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/775/Figure 3.png
# 0.30390167236328125
# Archivo: 775.pdf, Figura: Figure 3, Label: 0.0, Similaridad: tensor([[0.3039]], device='cuda:0')
# Performance policies different query rates biped left dog right Separate policies trained query rate
# 15
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/775/Figure 4.png
# 0.27057576179504395
# Archivo: 775.pdf, Figura: Figure 4, Label: 0.0, Similaridad: tensor([[0.2706]], device='cuda:0')
# Performance intermediate MTU policies actuator parameters per pass actuator optimization following Algorithm 2
# 15
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/775/Figure 5.png
# 0.22834934294223785
# Archivo: 775.pdf, Figura: Figure 5, Label: 0.0, Similaridad: tensor([[0.2283]], device='cuda:0')
# Learning curves comparing initial optimized MTU parameters
# 10
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/775/Figure 6.png
# 0.28221023082733154
# Archivo: 775.pdf, Figura: Figure 6, Label: 0.0, Similaridad: tensor([[0.2822]], device='cuda:0')
# Left fixed initial state biases agent regions state space near initial state particular early iterations training Right initial states sampled reference trajectory allows agent explore state space uniformly around reference trajectory
# 30
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/775/Figure 7.png
# 0.29814448952674866
# Archivo: 775.pdf, Figura: Figure 7, Label: 0.0, Similaridad: tensor([[0.2981]], device='cuda:0')
# Neural Network Architecture policy represented three layered network 512 256 fullyconnected hidden units followed linear output layer
# 23
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/775/Figure 8.png
# 0.3319813311100006
# Archivo: 775.pdf, Figura: Figure 8, Label: 0.0, Similaridad: tensor([[0.3320]], device='cuda:0')
# Training hyperparameters
# 5
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/775/Table 2.png
# 0.23202602565288544
# Archivo: 775.pdf, Figura: Table 2, Label: 0.0, Similaridad: tensor([[0.2320]], device='cuda:0')
# number state action actuation model parameters different characters actuation models
# 12
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/775/Table 3.png
# 0.3155613839626312
# Archivo: 775.pdf, Figura: Table 3, Label: 0.0, Similaridad: tensor([[0.3156]], device='cuda:0')
# Performance policies trained various characters actuation models Performance measured using normalized cumulative reward NCR learning speed represented normalized area learning curve AUC best performing parameterizations character motion bold
# 33
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/775/Table 4.png
# 0.27066269516944885
# Archivo: 775.pdf, Figura: Table 4, Label: 0.0, Similaridad: tensor([[0.2707]], device='cuda:0')
# Learning curves different random network initializations Four policies trained actuation model
# 16
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/775/Figure 9.png
# 0.2852696180343628
# Archivo: 775.pdf, Figura: Figure 9, Label: 0.0, Similaridad: tensor([[0.2853]], device='cuda:0')
# Learning curves comparing effects scaling standard deviation action distribution 1x 2x 12x
# 19
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/775/Figure 10.png
# 0.2725539207458496
# Archivo: 775.pdf, Figura: Figure 10, Label: 0.0, Similaridad: tensor([[0.2726]], device='cuda:0')
# Learning curves different network architectures network structures include doubling number units hidden layer halving number units inserting additional hidden layer 512 units two existing hidden layers
# 26
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/775/Figure 11.png
# 0.23908881843090057
# Archivo: 775.pdf, Figura: Figure 11, Label: 0.0, Similaridad: tensor([[0.2391]], device='cuda:0')
# Performance different action parameterizations traveling across randomly generated irregular terrain left Dog running across bumpy terrain height bump varies uniformly 0 specified maximum height middle right biped dog traveling across randomly generated slopes bounded maximum steepness
# 37
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/775/Figure 12.png
# 0.26659807562828064
# Archivo: 775.pdf, Figura: Figure 12, Label: 0.0, Similaridad: tensor([[0.2666]], device='cuda:0')
# Simulated Motions Using PD Action Representation top row uses MTU action space remainder driven PD action space
# 17
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/775/Figure 13.png
# 0.29221975803375244
# Archivo: 775.pdf, Figura: Figure 13, Label: 0.0, Similaridad: tensor([[0.2922]], device='cuda:0')
# Policy actions time resulting torques four action types Data one biped walk cycle 1s Left Actions 60 Hz right hip PD Vel Tor right gluteal muscle MTU Right Torques applied right hip joint sampled 600 Hz
# 40
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/775/Figure 14.png
# 0.28704458475112915
# Archivo: 775.pdf, Figura: Figure 14, Label: 0.0, Similaridad: tensor([[0.2870]], device='cuda:0')
# Learning curves different state representations including state target state state phase state
# 11
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/775/Figure 15.png
# 0.29049578309059143
# Archivo: 775.pdf, Figura: Figure 15, Label: 0.0, Similaridad: tensor([[0.2905]], device='cuda:0')
# Spatial contrasting depiction
# 5
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/791/Figure 1.png
# 0.25180935859680176
# Archivo: 791.pdf, Figura: Figure 1, Label: 0.0, Similaridad: tensor([[0.2518]], device='cuda:0')
# State art results STL10 dataset
# 10
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/791/Table 1.png
# 0.2469020038843155
# Archivo: 791.pdf, Figura: Table 1, Label: 0.0, Similaridad: tensor([[0.2469]], device='cuda:0')
# State art results Cifar10 dataset 4000 labeled samples
# 17
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/791/Table 2.png
# 0.30002903938293457
# Archivo: 791.pdf, Figura: Table 2, Label: 0.0, Similaridad: tensor([[0.3000]], device='cuda:0')
# results MNIST dataset
# 7
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/791/Table 3.png
# 0.25059688091278076
# Archivo: 791.pdf, Figura: Table 3, Label: 0.0, Similaridad: tensor([[0.2506]], device='cuda:0')
# Convolutional models used based Lin et al 2013 Rasmus et al 2015
# 21
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/791/Table 4.png
# 0.3407849669456482
# Archivo: 791.pdf, Figura: Table 4, Label: 0.0, Similaridad: tensor([[0.3408]], device='cuda:0')
# First layer convolutional filters spatialcontrasting training
# 12
# /content/drive/MyDrive/pruebasNadia/iclr_img/img_iclr/dev/791/Figure 2.png
# 0.2608015537261963
# Archivo: 791.pdf, Figura: Figure 2, Label: 0.0, Similaridad: tensor([[0.2608]], device='cuda:0')
#    archivo    figura                                       texto_figura  \
# 0  304.pdf  Figure 1  Addition Task. The non-recursive trace loops o...
# 1  304.pdf  Figure 2  Bubble Sort Task. The non-recursive trace loop...
# 2  304.pdf   Table 1  Accuracy on Randomly Generated Problems for Bu...
# 3  304.pdf   Table 2  Accuracy on Randomly Generated Problems for To...
# 4  304.pdf   Table 3  Accuracy on Randomly Generated Problems for Qu...
#
#    label                ruta  tamano  similaridad
# 0    NaN  img_iclr/train/304      24     0.295885
# 1    NaN  img_iclr/train/304      78     0.272177
# 2    NaN  img_iclr/train/304       8     0.264897
# 3    NaN  img_iclr/train/304       8     0.238954
# 4    NaN  img_iclr/train/304       7     0.284088
# Archivo CSV con las columnas 'tamano' y 'similaridad' guardado en: /content/drive/MyDrive/pruebasNadia/Extraer IMG/dataimg_iclr_similaridad_stopwords.csv
